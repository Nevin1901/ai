# %%
import numpy as np
from sklearn import metrics, datasets, discriminant_analysis, linear_model, kernel_ridge
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
(data_x, data_y) = datasets.load_diabetes(return_X_y=True, as_frame=True)
data_x = data_x["bmi"]
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.33, random_state=42)
# run LDA or PCA on the s1, s2, s3, s5, s6. Remove s3 as it has a negative correlation which could screw up the equation
# bmi, bp
plt.scatter(data_x, data_y)
# plt.tight_layout()
plt.show()

# %%
# reg = discriminant_analysis.().fit(train_x, train_y).transform(train_x)

# linear = linear_model.LinearRegression().fit(reg, train_y)
# print(np.asarray(train_x["bp"]))
# print(train_y.shape)
reg = linear_model.Ridge(alpha=0.5).fit(np.asarray(train_x).reshape(-1, 1), train_y)
print(reg.coef_)p
y_pred = reg.predict(np.asarray(test_x).reshae(-1, 1))
r2_score = metrics.r2_score(test_y, y_pred)
print(r2_score)
# Out:
# [556.84268776]
# 0.2726806173583509
